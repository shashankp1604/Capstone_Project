# %%
#Importing Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df1 = pd.read_csv('/content/drive/MyDrive/df4.csv')
df2 = pd.read_csv('/content/drive/MyDrive/df4_test.csv')

# %%
df2.drop(['uniqueID','date'],axis=1,inplace=True)

# %%
df = pd.concat([df1,df2],axis=0)

# %%
df['sentiment1'] = df["rating"].apply(lambda x: 1 if x > 5 else 0)

# %%
df.head()
# Out:
#    Unnamed: 0  ... sentiment1
# 0       42825  ...          0
# 1      121198  ...          1
# 2      126670  ...          1
# 3      113081  ...          0
# 4      150213  ...          1
#
# [5 rows x 9 columns]

# %%
df = df.dropna()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
cv = TfidfVectorizer(ngram_range=(2,2),max_features=5000)

X = cv.fit_transform(df['clean_review'].values).toarray()

# %%
y = df.sentiment1

# %%
X_train = X[0:50000]
X_test = X[50000:]

y_train = y[0:50000]
y_test = y[50000:]

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
nl_model = AdaBoostClassifier(random_state=0).fit(X_train, y_train)

y_pred_lemma_cv=nl_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
print('accuracy score:',accuracy_score(y_test,y_pred_lemma_cv))
# Out:
# accuracy score: 0.5995822036534957

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_lemma_cv))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.80      0.65     10688
#            1       0.70      0.42      0.52     11811
#
#     accuracy                           0.60     22499
#    macro avg       0.63      0.61      0.59     22499
# weighted avg       0.63      0.60      0.59     22499

# %%
from sklearn.metrics import precision_score , recall_score , f1_score
print('precision score:',precision_score(y_test,y_pred_lemma_cv))
print('recall score:',recall_score(y_test,y_pred_lemma_cv))
print('f1  score:',f1_score(y_test,y_pred_lemma_cv))
# Out:
# precision score: 0.6970464135021097
# recall score: 0.41960883921767844
# f1  score: 0.5238623751387347
